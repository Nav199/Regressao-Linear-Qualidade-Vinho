# %% [markdown]
# <a href="https://colab.research.google.com/github/Nav199/Regressao-Linear-Qualidade-Vinho/blob/main/Regress%C3%A3o_linear_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install seaborn

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
wines = pd.read_excel('/content/winequality-white (1).xlsx')

# %%
wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
wines.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
sns.heatmap(wines.corr())
# Out:
# <Axes: >

# %%
wines.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
X_columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']
y_columns = ['quality']

# %%
X = wines[X_columns]
y = wines[y_columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[ 9.46658323e-02, -1.82543795e+00,  3.07827695e-03,
#          1.04348518e-01, -2.77044766e-01,  4.17726945e-03,
#          8.34206575e-05, -2.23683929e+02,  7.91866647e-01,
#          7.40460470e-01,  1.05663168e-01]])

# %%
preds = lr.predict(X_test)

# %%
preds
# Out:
# array([[5.95318578],
#        [6.15820669],
#        [5.89609505],
#        ...,
#        [5.39849296],
#        [5.64762769],
#        [5.52980317]])

# %%
plt.scatter(y_test, preds)
plt.xlabel("valores esperados")
plt.ylabel("valores preditos")
# Out:
# Text(0, 0.5, 'valores preditos')

# %%
from sklearn.metrics import mean_squared_error

# %%
print(mean_squared_error(y_test, preds))
# Out:
# 0.5866032190118028
